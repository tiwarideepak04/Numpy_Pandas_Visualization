# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Take - home
#                         <br> (Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises.
#
# **Create a dataframe wherever necessary**

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Compute minimum and maximum sales for each store and location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
import pandas as pd
import numpy as np
data= [
    ['A','Mumbai',40000],
    ['B','Pune',45000],
    ['A','Hyderabad',50000],
    ['C','Mumbai',90000],
    ['D','Pune',89000],
    ['A','Delhi',87000],
    ['D','Hyderabad',85000],
    ['A','Pune',78000],
    ['C','Mumbai',89000],
    ['B','Pune',70000]
]
col = ['Store','Location','Sales']
df = pd.DataFrame(data,columns = col )
df

a = df.groupby(by = ['Location'])['Sales'].min()
print(a)
b = df.groupby(by = ['Store'])['Sales'].max()
print(b)
# Out:
# Location
# Delhi        87000
# Hyderabad    50000
# Mumbai       40000
# Pune         45000
# Name: Sales, dtype: int64
# Store
# A    87000
# B    70000
# C    90000
# D    89000
# Name: Sales, dtype: int64

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find duplicate rows based on the column 'Name'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachin</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
data = [
    ['John',3400,'Sydney'],
    ['Robert',3000,'Chicago'],
    ['Aadi',1600,'New York'],
    ['Robert',3000,'Chicago'],
    ['Robert',3000,'Chicago'],
    ['Robert',3000,'Texas'],
    ['Aadi',4000,'London'],
    ['Sachin',3000,'Chicago']
]
col = ['Name','Salary','City']

df = pd.DataFrame(data, columns = col)
df

df.duplicated('City')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# dtype: bool

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3.  In column tournament, replace all the 'football' values  with 'cricket' using numpy.where
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
d = [
    ['Mon','Football'],
    ['Tues','Cricket'],
    ['Wed','Football'],
    ['Thurs','Football'],
    ['Fri','Cricket'],
]
c = ['Days','Tournament']
df1 = pd.DataFrame(d, columns = c)
df1

x = np.where(df1 == 'Football', 'Cricket', df1)
x
# Out:
# array([['Mon', 'Cricket'],
#        ['Tues', 'Cricket'],
#        ['Wed', 'Cricket'],
#        ['Thurs', 'Cricket'],
#        ['Fri', 'Cricket']], dtype=object)

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Get the descriptive statistics of the sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
q = [
    ['Jan',22000,'Winter'],
    ['Feb',27000,'Winter'],
    ['Mar',25000,'Spring'],
    ['Apr',29000,'Spring'],
    ['May',35000,'Spring'],
    ['June',67000,'Summer'],
    ['July',78000,'Summer'],
    ['Aug',67000,'Summer'],
    ['Sep',56000,'Fall'],
    ['Oct',56000,'Fall'],
    ['Nov',56000,'Fall'],
    ['Dec',60000,'Winter']
]
col = ['Months','Sales','Seasons']
w = pd.DataFrame(q,columns= col)
print(w)
w.describe(include =[(np.number),(np.object)])
# Out:
#    Months  Sales Seasons
# 0     Jan  22000  Winter
# 1     Feb  27000  Winter
# 2     Mar  25000  Spring
# 3     Apr  29000  Spring
# 4     May  35000  Spring
# 5    June  67000  Summer
# 6    July  78000  Summer
# 7     Aug  67000  Summer
# 8     Sep  56000    Fall
# 9     Oct  56000    Fall
# 10    Nov  56000    Fall
# 11    Dec  60000  Winter
#        Months         Sales Seasons
# count      12     12.000000      12
# unique     12           NaN       4
# top       Apr           NaN  Spring
# freq        1           NaN       3
# mean      NaN  48166.666667     NaN
# std       NaN  19385.249000     NaN
# min       NaN  22000.000000     NaN
# 25%       NaN  28500.000000     NaN
# 50%       NaN  56000.000000     NaN
# 75%       NaN  61750.000000     NaN
# max       NaN  78000.000000     NaN

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Create a new column age with values of your choice. And append it to the below dataframe.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
a = [
    ['Emma',56,89,89],
    ['Mia',78,87,89],
    ['Sophia',78,78,76],
    ['James',67,89,78],
    ['John',88,78,87]
]
b = ['Name','Maths','Science','English']
c = pd.DataFrame(a,columns= b)
c

a1 = [
    [45],
    [22],
    [42],
    [65],
    [53]
]
b1 = ['Age']
c1 = pd.DataFrame(a1, columns=b1)
c1

#j = pd.concat([c,c1], axis = 1)
j = c.join(c1)
j
# Out:
#      Name  Maths  Science  English  Age
# 0    Emma     56       89       89   45
# 1     Mia     78       87       89   22
# 2  Sophia     78       78       76   42
# 3   James     67       89       78   65
# 4    John     88       78       87   53

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Perform right join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#         <td>Geography</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#         <td>History</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
f = [
    [101,'Alex','History'],
    [102,'Amy','English'],
    [103,'Allen','Geography'],
    [104,'Alice','German'],
    [105,'James','History']
]
y = ['Stud_ID','Name','MA(Hons)']

v =[
    [101,'Delhi','English'],
    [102,'Mumbai','History'],
    [103,'Delhi','Fine Arts'],
    [104,'Chennai','German'],
    [105,'Hyderabad','History']
]
w = ['Stud_ID','Res_City','MA(Hons)']
o = pd.DataFrame(v,columns= w)
print(o)

p = pd.DataFrame(f,columns= y)
print(p)

q = pd.merge(o,p, on ='MA(Hons)', how = 'right', sort = True )
q
# Out:
#    Stud_ID   Res_City   MA(Hons)
# 0      101      Delhi    English
# 1      102     Mumbai    History
# 2      103      Delhi  Fine Arts
# 3      104    Chennai     German
# 4      105  Hyderabad    History
#    Stud_ID   Name   MA(Hons)
# 0      101   Alex    History
# 1      102    Amy    English
# 2      103  Allen  Geography
# 3      104  Alice     German
# 4      105  James    History
#    Stud_ID_x   Res_City   MA(Hons)  Stud_ID_y   Name
# 0      101.0      Delhi    English        102    Amy
# 1        NaN        NaN  Geography        103  Allen
# 2      104.0    Chennai     German        104  Alice
# 3      102.0     Mumbai    History        101   Alex
# 4      105.0  Hyderabad    History        101   Alex
# 5      102.0     Mumbai    History        105  James
# 6      105.0  Hyderabad    History        105  James

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Using the dataframes created in question 6, perform inner join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(o)
print(p)

s = pd.merge(o,p, on=['Stud_ID','MA(Hons)'], how = 'inner')
s
# Out:
#    Stud_ID   Res_City   MA(Hons)
# 0      101      Delhi    English
# 1      102     Mumbai    History
# 2      103      Delhi  Fine Arts
# 3      104    Chennai     German
# 4      105  Hyderabad    History
#    Stud_ID   Name   MA(Hons)
# 0      101   Alex    History
# 1      102    Amy    English
# 2      103  Allen  Geography
# 3      104  Alice     German
# 4      105  James    History
#    Stud_ID   Res_City MA(Hons)   Name
# 0      104    Chennai   German  Alice
# 1      105  Hyderabad  History  James

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Concatenate two dataframes along the columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
t = [
    [101,'Alex'],
    [102,'Amy'],
    [103,'Allen'],
    [104,'Alice'],
    [105,'James'],
]
y = ['Stud_ID','Name']
l = pd.DataFrame(t,columns= y)
print(l)

j = [
    ['Delhi','English'],
    ['Mumbai','History'],
    ['Delhi','Fine Arts'],
    ['Chennai','German'],
    ['Hyderabad','History']
]
k = ['Res_City','MA(Hons)']
h = pd.DataFrame(j,columns= k)
print(h)

c = pd.concat(objs = (l,h), axis= 1)
c
# Out:
#    Stud_ID   Name
# 0      101   Alex
# 1      102    Amy
# 2      103  Allen
# 3      104  Alice
# 4      105  James
#     Res_City   MA(Hons)
# 0      Delhi    English
# 1     Mumbai    History
# 2      Delhi  Fine Arts
# 3    Chennai     German
# 4  Hyderabad    History
#    Stud_ID   Name   Res_City   MA(Hons)
# 0      101   Alex      Delhi    English
# 1      102    Amy     Mumbai    History
# 2      103  Allen      Delhi  Fine Arts
# 3      104  Alice    Chennai     German
# 4      105  James  Hyderabad    History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Calculate minimum, maximum and average sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
s = [
    [101,'Alex','Maths'],
    [102,'Amy','English'],
    [103,'Allen','Science'],
    [104,'Alice','German'],
    [105,'Ayoung','History']
]
i = ['ID','Name','Subject']
r = pd.DataFrame(s,columns= i)
print(r)

z = [
    [101,'Billy','English'],
    [102,'Brian','Science'],
    [103,'Bran','Social Science'],
    [104,'Bryce','German'],
    [105,'Betty','History']
]
c = ['ID','Name','Subject']
m = pd.DataFrame(z,columns= c)
print(m)
# Out:
#     ID    Name  Subject
# 0  101    Alex    Maths
# 1  102     Amy  English
# 2  103   Allen  Science
# 3  104   Alice   German
# 4  105  Ayoung  History
#     ID   Name         Subject
# 0  101  Billy         English
# 1  102  Brian         Science
# 2  103   Bran  Social Science
# 3  104  Bryce          German
# 4  105  Betty         History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Find all the duplicate entries based on the columns X and Y.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>X</th>
# <th>Y</th>
# <th>Z</th>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>5</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1</td>
# <td>2</td>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# </tr>
# <tr>
# <td>3</td>
# <td>4</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>2</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>8</td>
# </tr>
#
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
g = [
    [1,2,5],
    [2,2,6],
    [3,1,2],
    [1,2,6],
    [2,2,1],
    [3,4,6],
    [2,2,2],
    [2,2,8]
]
b = ['X','Y','Z']
r = pd.DataFrame(g,columns= b)
print(r)

r.duplicated(['X','Y'], keep = 'last')
# Out:
#    X  Y  Z
# 0  1  2  5
# 1  2  2  6
# 2  3  1  2
# 3  1  2  6
# 4  2  2  1
# 5  3  4  6
# 6  2  2  2
# 7  2  2  8
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
q = [
    ['Jan',22000,'Winter'],
    ['Feb',27000,'Winter'],
    ['Mar',25000,'Spring'],
    ['Apr',29000,'Spring'],
    ['May',35000,'Spring'],
    ['June',67000,'Summer'],
    ['July',78000,'Summer'],
    ['Aug',67000,'Summer'],
    ['Sep',56000,'Fall'],
    ['Oct',56000,'Fall'],
    ['Nov',56000,'Fall'],
    ['Dec',60000,'Winter']
]
col = ['Months','Sales','Seasons']
w = pd.DataFrame(q,columns= col)
print(w)

w.duplicated(['Sales'], keep = 'last')
# Out:
#    Months  Sales Seasons
# 0     Jan  22000  Winter
# 1     Feb  27000  Winter
# 2     Mar  25000  Spring
# 3     Apr  29000  Spring
# 4     May  35000  Spring
# 5    June  67000  Summer
# 6    July  78000  Summer
# 7     Aug  67000  Summer
# 8     Sep  56000    Fall
# 9     Oct  56000    Fall
# 10    Nov  56000    Fall
# 11    Dec  60000  Winter
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# dtype: bool
